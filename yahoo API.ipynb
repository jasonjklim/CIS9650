# %% [markdown]
# ## Use following website for installing Yahoo finance data from Pypi
#
# https://pypi.org/project/fix-yahoo-finance/
#
# reference site
#
# https://pypi.org/project/yfinance/

# %%
import yfinance as yf
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)
import seaborn as sns

# %%
msft = yf.Ticker("MSFT")
print(msft)
# Out:
# yfinance.Ticker object <MSFT>

# %%
msft.history(period="max")
# Out:
#               Open    High     Low   Close      Volume  Dividends  \
# Date
# 1986-03-13    0.06    0.07    0.06    0.06  1031788800        0.0
# 1986-03-14    0.06    0.07    0.06    0.06   308160000        0.0
# 1986-03-17    0.06    0.07    0.06    0.07   133171200        0.0
# 1986-03-18    0.07    0.07    0.06    0.06    67766400        0.0
# 1986-03-19    0.06    0.06    0.06    0.06    47894400        0.0
# ...            ...     ...     ...     ...         ...        ...
# 2019-12-02  151.81  151.83  148.32  149.55    27418400        0.0
# 2019-12-03  147.49  149.43  146.65  149.31    24066000        0.0
# 2019-12-04  150.14  150.18  149.20  149.85    17574700        0.0
# 2019-12-05  150.05  150.32  149.48  149.93    17869100        0.0
# 2019-12-06  150.99  151.87  150.27  151.75    16410400        0.0
#
#             Stock Splits
# Date
# 1986-03-13           0.0
# 1986-03-14           0.0
# 1986-03-17           0.0
# 1986-03-18           0.0
# 1986-03-19           0.0
# ...

# %%
start_date= "2018-01-01"
end_date= "2018-12-31"
stoc

ks = "SPY QQQ AAPL MSFT T VZ GOOG AMZN FB BABA JNJ JPM BAC WFC BUD CVX UNH INTC SBUX WMT V TSLA XOM DIS KO C NFLX GE IBM MCD"

# %%
data = yf.download(stocks, start=start_date, end=end_date)['Adj Close']
# Out:
# [*********************100%***********************]  30 of 30 completed

# %%
data
# Out:
#                   AAPL         AMZN        BABA        BAC         BUD  \
# Date
# 2018-01-02  167.199890  1189.010010  183.649994  28.707111  105.872871
# 2018-01-03  167.170776  1204.199951  184.000000  28.611095  106.692215
# 2018-01-04  167.947266  1209.589966  185.710007  28.985540  106.984154
# 2018-01-05  169.859406  1229.140015  190.699997  29.119955  108.057770
# 2018-01-08  169.228500  1246.869995  190.330002  28.918331  107.313774
# 2018-01-09  169.209091  1252.699951  190.800003  29.062347  107.671638
# 2018-01-10  169.170258  1254.329956  189.789993  29.331177  107.285522
# 2018-01-11  170.131180  1276.680054  188.750000  29.436789  107.549210
# 2018-01-12  171.888031  1305.199951  187.789993  29.945644  108.208443
# 2018-01-16  171.014465  1304.859985  182.399994  29.993649  108.811172
# 2018-01-17  173.839005  1295.000000  183.830002  29.936041  109.225555
# 2018-01-18  173.994293  1293.319946  184.399994  30.224072  108.415634
# ...

# %%
sns.heatmap(data.corr())
